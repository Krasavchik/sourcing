# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from datetime import datetime, timedelta

# Input: URL of the website
# Get the current date
current_date = datetime.now()

# Subtract one day to get yesterday's date
yesterday_date = current_date - timedelta(days=1)

# Format the date as YYYY/MM/DD
formatted_date = yesterday_date.strftime("%Y/%m/%d")

# Build the URL
base_url = "https://nightly.changelog.com"
input_url = f"{base_url}/{formatted_date}"
filename = f"exports/export_changelog_{yesterday_date.year}_{yesterday_date.month:02d}_{yesterday_date.day:02d}.csv"

# Build the exclusion list
exclusion_list = ["https://github.com/thechangelog", "https://github.com/trending", "https://github.com/NVIDIA"]
# Out:
# /Users/matthieulavergne/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Function to scrape all URLs from the given website
def scrape_urls(website_url):
    try:
        response = requests.get(website_url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all anchor tags
        links = [a.get('href') for a in soup.find_all('a', href=True)]
        return links
    except requests.RequestException as e:
        print(f"Error accessing {website_url}: {e}")
        return []

# Function to check if a URL redirects to github.com
def check_redirect_to_github(url):
    try:
        response = requests.head(url, allow_redirects=True, timeout=5)
        if 'github.com' in response.url:
            return True, response.url
    except requests.RequestException:
        pass
    return False, None

# Function to check if a URL is a GitHub repository
def is_github_repo(url):
    pattern = r"^https://github\.com/([^/]+)/([^/]+)$"
    match = re.match(pattern, url)
    if match:
        author = f"https://github.com/{match.group(1)}"
        repo = url
        return True, author, repo
    return False, None, None

# Step 1: Scrape all URLs from the input URL
print("Scraping URLs...")
urls = scrape_urls(input_url)

# Count the number of items in the data list
urls_count = len(urls)
print(f"Number of items in the initial url list: {urls_count}")
# Out:
# Scraping URLs...
# Number of items in the initial url list: 94

# %%
# Step 2: Check for redirection to github.com
print("Checking for redirects to github.com...")
github_redirects = pd.DataFrame(columns=["Repo", "Repo_name", "Repo_desc" , "Star_count" , "Author", "Name", "Type", "Website", "Bio", "Location"])
for url in urls:
    if not url.startswith("http"):
        url = requests.compat.urljoin(input_url, url)  # Handle relative URLs
    is_redirect, redirected_url = check_redirect_to_github(url)
    if is_redirect:
        is_repo, author, repo = is_github_repo(redirected_url)
        if is_repo:
            github_redirects = pd.concat([
                github_redirects, 
                pd.DataFrame([{"Repo": repo, "Author": author}])
            ], ignore_index=True)

row_count = len(github_redirects)
print(f"Number of repos: {row_count}")
github_redirects.head(50)
# Out:
# Checking for redirects to github.com...
# Number of repos: 42
#                                                  Repo Repo_name Repo_desc  \
# 0             https://github.com/thechangelog/nightly       NaN       NaN
# 1      https://github.com/henrythe9th/AI-Crash-Course       NaN       NaN
# 2     https://github.com/StellarSand/privacy-settings       NaN       NaN
# 3                  https://github.com/trending/python       NaN       NaN
# 4                 https://github.com/PriorLabs/TabPFN       NaN       NaN
# 5                  https://github.com/trending/kotlin       NaN       NaN
# 6             https://github.com/rifsxd/KernelSU-Next       NaN       NaN
# 7              https://github.com/trending/typescript       NaN       NaN
# 8                https://github.com/PollensAI/Pollens       NaN       NaN
# 9              https://github.com/trending/javascript       NaN       NaN
# 10            https://github.com/ASITHA-MD/ASITHA-BOT       NaN       NaN
# 11                      https://github.com/trending/c       NaN       NaN
# 12         https://github.com/polarsignals/kubezonnet       NaN       NaN
# 13                    https://github.com/trending/lua       NaN       NaN
# 14        https://github.com/jackplus-xyz/binary.nvim       NaN       NaN
# 15             https://github.com/trending/typescript       NaN       NaN
# 16  https://github.com/lio-mengxiang/eslint9-quick...       NaN       NaN
# 17             https://github.com/trending/javascript       NaN       NaN
# 18  https://github.com/SILENTLOVER40/SILENT-SOBX-M...       NaN       NaN
# 19                  https://github.com/trending/swift       NaN       NaN
# 20      https://github.com/harlanhaskins/MorphingView       NaN       NaN
# 21             https://github.com/trending/typescript       NaN       NaN
# 22              https://github.com/inkonchain/ink-kit       NaN       NaN
# 23             https://github.com/trending/typescript       NaN       NaN
# 24           https://github.com/browserbase/stagehand       NaN       NaN
# 25                 https://github.com/trending/python       NaN       NaN
# 26              https://github.com/browser-use/web-ui       NaN       NaN
# 27          https://github.com/SagiPolaczek/NeuralSVG       NaN       NaN
# 28                      https://github.com/trending/c       NaN       NaN
# 29                https://github.com/78/xiaozhi-esp32       NaN       NaN
# 30             https://github.com/trending/typescript       NaN       NaN
# 31                     https://github.com/cline/cline       NaN       NaN
# 32                      https://github.com/trending/c       NaN       NaN
# 33  https://github.com/nuta/operating-system-in-10...       NaN       NaN
# 34                 https://github.com/trending/python       NaN       NaN
# 35          https://github.com/All-Hands-AI/OpenHands       NaN       NaN
# 36                 https://github.com/trending/python       NaN       NaN
# 37         https://github.com/browser-use/browser-use       NaN       NaN
# 38             https://github.com/trending/typescript       NaN       NaN
# 39       https://github.com/ammaarreshi/Gemini-Search       NaN       NaN
# 40             https://github.com/trending/typescript       NaN       NaN
# 41                 https://github.com/langgenius/dify       NaN       NaN
#
#    Star_count                            Author Name Type Website  Bio  \
# 0         NaN   https://github.com/thechangelog  NaN  NaN     NaN  NaN
# 1         NaN    https://github.com/henrythe9th  NaN  NaN     NaN  NaN
# 2         NaN    https://github.com/StellarSand  NaN  NaN     NaN  NaN
# 3         NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 4         NaN      https://github.com/PriorLabs  NaN  NaN     NaN  NaN
# 5         NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 6         NaN         https://github.com/rifsxd  NaN  NaN     NaN  NaN
# 7         NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 8         NaN      https://github.com/PollensAI  NaN  NaN     NaN  NaN
# 9         NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 10        NaN      https://github.com/ASITHA-MD  NaN  NaN     NaN  NaN
# 11        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 12        NaN   https://github.com/polarsignals  NaN  NaN     NaN  NaN
# 13        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 14        NaN   https://github.com/jackplus-xyz  NaN  NaN     NaN  NaN
# 15        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 16        NaN  https://github.com/lio-mengxiang  NaN  NaN     NaN  NaN
# 17        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 18        NaN  https://github.com/SILENTLOVER40  NaN  NaN     NaN  NaN
# 19        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 20        NaN  https://github.com/harlanhaskins  NaN  NaN     NaN  NaN
# 21        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 22        NaN     https://github.com/inkonchain  NaN  NaN     NaN  NaN
# 23        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 24        NaN    https://github.com/browserbase  NaN  NaN     NaN  NaN
# 25        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 26        NaN    https://github.com/browser-use  NaN  NaN     NaN  NaN
# 27        NaN   https://github.com/SagiPolaczek  NaN  NaN     NaN  NaN
# 28        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 29        NaN             https://github.com/78  NaN  NaN     NaN  NaN
# 30        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 31        NaN          https://github.com/cline  NaN  NaN     NaN  NaN
# 32        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 33        NaN           https://github.com/nuta  NaN  NaN     NaN  NaN
# 34        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 35        NaN   https://github.com/All-Hands-AI  NaN  NaN     NaN  NaN
# 36        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 37        NaN    https://github.com/browser-use  NaN  NaN     NaN  NaN
# 38        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 39        NaN    https://github.com/ammaarreshi  NaN  NaN     NaN  NaN
# 40        NaN       https://github.com/trending  NaN  NaN     NaN  NaN
# 41        NaN     https://github.com/langgenius  NaN  NaN     NaN  NaN
#
#    Location
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN
# 33      NaN
# 34      NaN
# 35      NaN
# 36      NaN
# 37      NaN
# 38      NaN
# 39      NaN
# 40      NaN
# 41      NaN

# %%
for index, row in github_redirects.iterrows():
    if row['Author'] in exclusion_list:
        github_redirects.drop(index, inplace=True)

row_count = len(github_redirects)
print(f"Number of repos after exclusion: {row_count}")

print(f"Repos list after exclusion:")
github_redirects.head(50)
# Out:
# Number of repos after exclusion: 22
# Repos list after exclusion:
#                                                  Repo Repo_name Repo_desc  \
# 1      https://github.com/henrythe9th/AI-Crash-Course       NaN       NaN
# 2     https://github.com/StellarSand/privacy-settings       NaN       NaN
# 4                 https://github.com/PriorLabs/TabPFN       NaN       NaN
# 6             https://github.com/rifsxd/KernelSU-Next       NaN       NaN
# 8                https://github.com/PollensAI/Pollens       NaN       NaN
# 10            https://github.com/ASITHA-MD/ASITHA-BOT       NaN       NaN
# 12         https://github.com/polarsignals/kubezonnet       NaN       NaN
# 14        https://github.com/jackplus-xyz/binary.nvim       NaN       NaN
# 16  https://github.com/lio-mengxiang/eslint9-quick...       NaN       NaN
# 18  https://github.com/SILENTLOVER40/SILENT-SOBX-M...       NaN       NaN
# 20      https://github.com/harlanhaskins/MorphingView       NaN       NaN
# 22              https://github.com/inkonchain/ink-kit       NaN       NaN
# 24           https://github.com/browserbase/stagehand       NaN       NaN
# 26              https://github.com/browser-use/web-ui       NaN       NaN
# 27          https://github.com/SagiPolaczek/NeuralSVG       NaN       NaN
# 29                https://github.com/78/xiaozhi-esp32       NaN       NaN
# 31                     https://github.com/cline/cline       NaN       NaN
# 33  https://github.com/nuta/operating-system-in-10...       NaN       NaN
# 35          https://github.com/All-Hands-AI/OpenHands       NaN       NaN
# 37         https://github.com/browser-use/browser-use       NaN       NaN
# 39       https://github.com/ammaarreshi/Gemini-Search       NaN       NaN
# 41                 https://github.com/langgenius/dify       NaN       NaN
#
#    Star_count                            Author Name Type Website  Bio  \
# 1         NaN    https://github.com/henrythe9th  NaN  NaN     NaN  NaN
# 2         NaN    https://github.com/StellarSand  NaN  NaN     NaN  NaN
# 4         NaN      https://github.com/PriorLabs  NaN  NaN     NaN  NaN
# 6         NaN         https://github.com/rifsxd  NaN  NaN     NaN  NaN
# 8         NaN      https://github.com/PollensAI  NaN  NaN     NaN  NaN
# 10        NaN      https://github.com/ASITHA-MD  NaN  NaN     NaN  NaN
# 12        NaN   https://github.com/polarsignals  NaN  NaN     NaN  NaN
# 14        NaN   https://github.com/jackplus-xyz  NaN  NaN     NaN  NaN
# 16        NaN  https://github.com/lio-mengxiang  NaN  NaN     NaN  NaN
# 18        NaN  https://github.com/SILENTLOVER40  NaN  NaN     NaN  NaN
# 20        NaN  https://github.com/harlanhaskins  NaN  NaN     NaN  NaN
# 22        NaN     https://github.com/inkonchain  NaN  NaN     NaN  NaN
# 24        NaN    https://github.com/browserbase  NaN  NaN     NaN  NaN
# 26        NaN    https://github.com/browser-use  NaN  NaN     NaN  NaN
# 27        NaN   https://github.com/SagiPolaczek  NaN  NaN     NaN  NaN
# 29        NaN             https://github.com/78  NaN  NaN     NaN  NaN
# 31        NaN          https://github.com/cline  NaN  NaN     NaN  NaN
# 33        NaN           https://github.com/nuta  NaN  NaN     NaN  NaN
# 35        NaN   https://github.com/All-Hands-AI  NaN  NaN     NaN  NaN
# 37        NaN    https://github.com/browser-use  NaN  NaN     NaN  NaN
# 39        NaN    https://github.com/ammaarreshi  NaN  NaN     NaN  NaN
# 41        NaN     https://github.com/langgenius  NaN  NaN     NaN  NaN
#
#    Location
# 1       NaN
# 2       NaN
# 4       NaN
# 6       NaN
# 8       NaN
# 10      NaN
# 12      NaN
# 14      NaN
# 16      NaN
# 18      NaN
# 20      NaN
# 22      NaN
# 24      NaN
# 26      NaN
# 27      NaN
# 29      NaN
# 31      NaN
# 33      NaN
# 35      NaN
# 37      NaN
# 39      NaN
# 41      NaN

# %%
GITHUB_TOKEN = "INSERT TOKEN HERE"

def get_github_author_info(author_url):
    username = author_url.split("https://github.com/")[-1]
    api_url = f"https://api.github.com/users/{username}"
    headers={
        "Accept": "application/vnd.github.v3+json",
        "Authorization": "Bearer INSERT TOKEN HERE"
    }
    try:
        response = requests.get(api_url, headers=headers)  # Pass headers as a keyword argument
        response.raise_for_status()
        user_data = response.json()
        user_name = user_data.get("name")
        user_type = user_data.get("type")
        blog = user_data.get("blog") or "No website"
        bio = user_data.get("bio") or "No bio"
        location = user_data.get("location") or "No location"
        return user_name, user_type, blog, bio, location
    except requests.RequestException as e:
        print(f"Error fetching data for {username}: {e}")
        return None, "No website", "No bio", "No location"
    

def query_github_repo(repo_url):
    if not repo_url.startswith("https://github.com/"):
        raise ValueError("Invalid GitHub repository URL")

    # Extract the owner and repo name from the URL
    parts = repo_url.split("https://github.com/")[-1].split("/")
    if len(parts) < 2:
        raise ValueError("Incomplete GitHub repository URL")

    owner, repo = parts[:2]

    # Construct the API call
    api_url = f"https://api.github.com/repos/{owner}/{repo}"
    headers={
        "Accept": "application/vnd.github.v3+json",
        "Authorization": "Bearer INSERT TOKEN HERE"
    }
    try:
        response = requests.get(api_url, headers=headers)  # Pass headers as a keyword argument
        response.raise_for_status()
        repo_data = response.json()

        # Extract required information
        repo_name = repo_data.get("name", "Unknown Repo")
        repo_description = repo_data.get("description", "No description available")
        star_count = repo_data.get("stargazers_count", 0)

        return repo_name, repo_description, star_count
    except requests.RequestException as e:
        print(f"Error querying GitHub API: {e}")
        return None, None, None


for index, row in github_redirects.iterrows():
    user_name, user_type, blog, bio, location = get_github_author_info(row['Author'])
    repo_name, repo_desc, star_count = query_github_repo(row['Repo'])
    github_redirects.at[index, 'Repo_name'] = repo_name
    github_redirects.at[index, 'Repo_desc'] = repo_desc
    github_redirects.at[index, 'Star_count'] = star_count  # Fixed the column name
    github_redirects.at[index, 'Name'] = user_name
    github_redirects.at[index, 'Type'] = user_type
    github_redirects.at[index, 'Website'] = blog
    github_redirects.at[index, 'Bio'] = bio
    github_redirects.at[index, 'Location'] = location
    print(star_count)

github_redirects['Star_count'] = pd.to_numeric(github_redirects['Star_count'], errors='coerce')

df = github_redirects.copy()
df.head(40)
# Out:
# 1031
# 877
# 1702
# 117
# 301
# 25
# 32
# 23
# 23
# 16
# 11
# 18681
# 3912
# 1979
# 771
# 2199
# 21122
# 966
# 42722
# 12277
# 1522
# 58022
#                                                  Repo  \
# 1      https://github.com/henrythe9th/AI-Crash-Course
# 2     https://github.com/StellarSand/privacy-settings
# 4                 https://github.com/PriorLabs/TabPFN
# 6             https://github.com/rifsxd/KernelSU-Next
# 8                https://github.com/PollensAI/Pollens
# 10            https://github.com/ASITHA-MD/ASITHA-BOT
# 12         https://github.com/polarsignals/kubezonnet
# 14        https://github.com/jackplus-xyz/binary.nvim
# 16  https://github.com/lio-mengxiang/eslint9-quick...
# 18  https://github.com/SILENTLOVER40/SILENT-SOBX-M...
# 20      https://github.com/harlanhaskins/MorphingView
# 22              https://github.com/inkonchain/ink-kit
# 24           https://github.com/browserbase/stagehand
# 26              https://github.com/browser-use/web-ui
# 27          https://github.com/SagiPolaczek/NeuralSVG
# 29                https://github.com/78/xiaozhi-esp32
# 31                     https://github.com/cline/cline
# 33  https://github.com/nuta/operating-system-in-10...
# 35          https://github.com/All-Hands-AI/OpenHands
# 37         https://github.com/browser-use/browser-use
# 39       https://github.com/ammaarreshi/Gemini-Search
# 41                 https://github.com/langgenius/dify
#
#                          Repo_name  \
# 1                  AI-Crash-Course
# 2                 privacy-settings
# 4                           TabPFN
# 6                    KernelSU-Next
# 8                          Pollens
# 10                      ASITHA-BOT
# 12                      kubezonnet
# 14                     binary.nvim
# 16       eslint9-quick-config-tool
# 18               SILENT-SOBX-MD-V2
# 20                    MorphingView
# 22                         ink-kit
# 24                       stagehand
# 26                          web-ui
# 27                       NeuralSVG
# 29                   xiaozhi-esp32
# 31                           cline
# 33  operating-system-in-1000-lines
# 35                       OpenHands
# 37                     browser-use
# 39                   Gemini-Search
# 41                            dify
#
#                                             Repo_desc Star_count  \
# 1   AI Crash Course to help busy builders catch up...        NaN
# 2   Guide to privacy settings for most major softw...        NaN
# 4       ⚡ TabPFN: Foundation Model for Tabular Data ⚡        NaN
# 6            A Kernel based root solution for Android        NaN
# 8   Buzz Together in Real Time: Your BeeSync for C...        NaN
# 10                             Asitha-md whatsapp bot        NaN
# 12  Monitor cross-zone network traffic in Kubernetes.        NaN
# 14  A minmal Neovim colorscheme using only two col...        NaN
# 16  it's a cli tool to help you update eslint 9.x ...        NaN
# 18  ✧〖THE WORLD BEST WHATSAPP BOT CREATED BY SILEN...        NaN
# 20    A morphing container view for UIKit and SwiftUI        NaN
# 22  Onchain-focused SDK with ready-to-use template...        NaN
# 24  An AI web browsing framework focused on simpli...        NaN
# 26                      Run AI Agent in your browser.        NaN
# 27               Official implementation of NerualSVG        NaN
# 29                           Build your own AI friend        NaN
# 31  Autonomous coding agent right in your IDE, cap...        NaN
# 33                      Writing an OS in 1,000 lines.        NaN
# 35                  🙌 OpenHands: Code Less, Make More        NaN
# 37             Make websites accessible for AI agents        NaN
# 39  Perplexity style AI Search engine clone built ...        NaN
# 41  Dify is an open-source LLM app development pla...        NaN
#
#                               Author            Name          Type  \
# 1     https://github.com/henrythe9th       Henry Shi          User
# 2     https://github.com/StellarSand     StellarSand          User
# 4       https://github.com/PriorLabs      Prior Labs  Organization
# 6          https://github.com/rifsxd      Rifat Azad          User
# 8       https://github.com/PollensAI         Pollens  Organization
# 10      https://github.com/ASITHA-MD            None          User
# 12   https://github.com/polarsignals   Polar Signals  Organization
# 14   https://github.com/jackplus-xyz      Jack Huang          User
# 16  https://github.com/lio-mengxiang           孟祥_成都          User
# 18  https://github.com/SILENTLOVER40  SILENTLOVER432          User
# 20  https://github.com/harlanhaskins  Harlan Haskins          User
# 22     https://github.com/inkonchain      inkonchain  Organization
# 24    https://github.com/browserbase            None  Organization
# 26    https://github.com/browser-use     Browser Use  Organization
# 27   https://github.com/SagiPolaczek   Sagi Polaczek          User
# 29             https://github.com/78         Xiaoxia          User
# 31          https://github.com/cline           Cline  Organization
# 33           https://github.com/nuta      Seiya Nuta          User
# 35   https://github.com/All-Hands-AI    All Hands AI  Organization
# 37    https://github.com/browser-use     Browser Use  Organization
# 39    https://github.com/ammaarreshi          ammaar          User
# 41     https://github.com/langgenius      LangGenius  Organization
#
#                                             Website  \
# 1                                     www.super.com
# 2                                        No website
# 4                          https://www.priorlabs.ai
# 6                                        No website
# 8                                       pollens.app
# 10                                       No website
# 12                        https://polarsignals.com/
# 14                             https://jackplus.xyz
# 16      https://juejin.cn/user/96412752684744/posts
# 18  https://github.com/SILENTLOVER40/SILENT-SOBX-MD
# 20                    https://www.harlanhaskins.com
# 22                           https://inkonchain.com
# 24                          https://browserbase.com
# 26                          https://browser-use.com
# 27                                       No website
# 29                                      xiaoxia.org
# 31                                https://cline.bot
# 33                                 https://seiya.me
# 35                           https://all-hands.dev/
# 37                          https://browser-use.com
# 39                                        ammaar.me
# 41                                  https://dify.ai
#
#                                                   Bio  \
# 1   Co-Founder of Super.com. Recently Reactivated ...
# 2                                              No bio
# 4                                              No bio
# 6                                          Tired.....
# 8   Buzz Together in Real Time: Your BeeSync for C...
# 10                                             No bio
# 12                                             No bio
# 14  A software engineer who has a dream to liberat...
# 16     keep making progress，永远保持一颗学习的心 微信：a2298613245
# 18  "✰°☆   ⃝   ᎠoᴎT wAꙅTɘ Uᴙ Timɘ To impᴙɘꙅꙅ mɘ   ...
# 20  Software engineer specializing in Apple platfo...
# 22                                             No bio
# 24                                             No bio
# 26                                             No bio
# 27                                                 🦜
# 29                                             No bio
# 31                                             No bio
# 33                                             No bio
# 35  We build AI software development agents for ev...
# 37                                             No bio
# 39                        Head of Design @elevenlabs
# 41  Dify is an LLMOps platform that helps you buil...
#
#                     Location  Start_count
# 1              San Francisco       1031.0
# 2                   Planet 3        877.0
# 4                No location       1702.0
# 6                No location        117.0
# 8                No location        301.0
# 10               No location         25.0
# 12               No location         32.0
# 14               No location         23.0
# 16                        成都         23.0
# 18                  PAKISTAN         16.0
# 20                       NYC         11.0
# 22               No location      18681.0
# 24  United States of America       3912.0
# 26  United States of America       1979.0
# 27               No location        771.0
# 29                     Earth       2199.0
# 31               No location      21122.0
# 33              Tokyo, Japan        966.0
# 35               No location      42722.0
# 37  United States of America      12277.0
# 39               No location       1522.0
# 41               No location      58022.0

# %%
github_redirects = github_redirects.sort_values(by='Type', ascending=True)
github_redirects.to_csv(filename, index=False)
print(input_url)
# Out:
# https://nightly.changelog.com/2025/01/09

# %%
def get_rate_limit():
    api_url = "https://api.github.com/rate_limit"
    headers = {
        "Accept": "application/vnd.github.v3+json",
        "Authorization": "Bearer INSERT TOKEN HERE"
    }
    try:
        # Query the GitHub API
        response = requests.get(api_url, headers=headers)  # Pass headers as a keyword argument
        response.raise_for_status()
        rate_limit_data = response.json()

        # Extract rate limit information
        remaining = rate_limit_data['rate']['remaining']
        limit = rate_limit_data['rate']['limit']
        reset_time = rate_limit_data['rate']['reset']

        print(f"Rate Limit: {limit}, Remaining: {remaining}, Resets at: {reset_time}")
    except requests.RequestException as e:
        print(f"Error fetching rate limit data: {e}")

# Call the function
get_rate_limit()
# Out:
# Rate Limit: 5000, Remaining: 5000, Resets at: 1736508224
